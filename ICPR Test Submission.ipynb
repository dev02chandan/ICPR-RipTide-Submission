# %%
# !wget --no-check https://mobility.iiit.ac.in/dataset/rip_test_set/VGG16_test_features.zip
# !unzip VGG16_test_features.zip

# %%
import os
import glob
import numpy as np

def check_files(rootdir):
    views = ['frontal_view/VGG16_features', 'left_view', 'right_view']
    file_shapes = {view: [] for view in views}

    for view in views:
        file_paths = glob.glob(os.path.join(rootdir, view, '*.npy'))
        for file_path in file_paths:
            try:
                data = np.load(file_path)
                file_shapes[view].append((file_path, data.shape))
            except Exception as e:
                print(f"Error loading {file_path}: {e}")

    return file_shapes

# %%
# !ls /content/VGG16_test_features/frontal_view/VGG16_features | wc -l
# There were some corrupt / incorrect files. Since our dataloader was crashing, we had to find them manually.
# !rm /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/09a30412-fd64-4ba0-8d5d-8fa5bd68b9e0.npy
# !rm /kaggle/working/VGG16_test_features/left_view/09a30412-fd64-4ba0-8d5d-8fa5bd68b9e0.npy
# !rm /kaggle/working/VGG16_test_features/right_view/09a30412-fd64-4ba0-8d5d-8fa5bd68b9e0.npy

# %%
# Path to your dataset
# rootdir = '/kaggle/input/riptide-test-new/VGG16_test_features'
rootdir = "/kaggle/working/VGG16_test_features"

file_shapes = check_files(rootdir)

# Print the shapes of the files
for view, shapes in file_shapes.items():
    print(f"\nView: {view}")
    for file_path, shape in shapes:
        print(f"File: {file_path}, Shape: {shape}")

# Save the shapes to a text file for further analysis if needed
with open('file_shapes.txt', 'w') as f:
    for view, shapes in file_shapes.items():
        f.write(f"\nView: {view}\n")
        for file_path, shape in shapes:
            f.write(f"File: {file_path}, Shape: {shape}\n")
# Out:
# View: frontal_view/VGG16_features
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/bd0e6ef3-0ee3-42d2-ba89-87e27f31da87.npy, Shape: (360, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/b8cf26e4-7329-4cfa-aca7-00bd40975ff0.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/60ad70f9-ecde-4f47-87ec-41bbc1221d94.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/7d43bedb-13c3-4b9d-9050-f1652b110a1e.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/dec19835-0fb4-4887-8178-19df3b497153.npy, Shape: (254, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/ab0832d7-1a2b-43a6-bec7-10cb25ca7983.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/66e56d2d-d4c4-42d2-b5b7-eb141fbd097f.npy, Shape: (156, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/02d9a67f-cd75-4880-9e41-08b9369e5ded.npy, Shape: (202, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/30b2c119-7f65-4791-afc4-93bbd8a2592f.npy, Shape: (300, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/cab48330-ac2b-4218-b05c-d0806e735bd5.npy, Shape: (156, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/13d1aac7-01e8-4d8f-be04-6b9bf1d78c38.npy, Shape: (254, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/bf900a43-4579-4031-b2e5-0fa24c7e00d4.npy, Shape: (142, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/5715a0a6-7fa2-4b5b-8f42-d43fcab9729a.npy, Shape: (202, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/acc2b4ae-1de1-4875-b4b8-3731eab75219.npy, Shape: (510, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/08fad321-94d6-4a5d-9203-4b76e0e26589.npy, Shape: (270, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/dc6efa69-6946-4e2b-9de4-288cbf3c20a6.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/2589beef-c7bc-4aff-a0f7-834cf661ce8b.npy, Shape: (300, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/35c62f85-9117-49e7-89d3-fa381057ae8d.npy, Shape: (480, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/ad26369a-749b-4222-a86f-055ea43d9291.npy, Shape: (104, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/505b42c8-9c46-4955-936f-16bfac5b8830.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/ac34341c-f835-499e-8706-b143adbabc5e.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/3be87140-9bcf-4eff-91d4-1795e3e5802d.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/9aaf8611-a2bc-4f1d-97c5-10e469d76456.npy, Shape: (194, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/6e117e55-f0dc-4305-834c-a5c8b29c7d3f.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/9fff9170-316b-468e-9ebd-1b3070fade5b.npy, Shape: (194, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/d3f77ea2-8db9-458b-b33a-e8024c77f566.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/5b2c6d24-4b3d-46ff-adef-b732508b3bb5.npy, Shape: (232, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/3a687a03-9d61-4741-9ef3-c54986769657.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/18148502-eb8a-49a1-a95d-76a02852a9cc.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/4a9bd7f9-da7d-4f31-a846-b732853d7aa4.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/fa1b0774-22d2-4411-ba35-734c2d7467c5.npy, Shape: (210, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/fc9b8169-9f71-446b-bb0c-cd05283e61e5.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/33993e5f-d42e-469a-bc34-dfb5fdf4edf6.npy, Shape: (120, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/8e069130-c58e-4778-b53b-b662556b54ed.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/6613d10d-3f50-4a79-a013-cc5da63f95b1.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/1d98d9d5-ad45-46ff-b3c2-f22546b2a7e3.npy, Shape: (480, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/2eac9b90-e267-4d92-852b-79b65002828e.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/13908178-9a4e-4862-ab9d-25ada8717d2c.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/41a79829-f926-4f7d-9d7a-630f6cace179.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/f3dc043b-39fb-438d-b170-e4fc7413a9ec.npy, Shape: (330, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/ed875a76-8c9a-4188-9a9b-c4a2c681b829.npy, Shape: (90, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/9407075f-f54b-4aa8-adbb-2f96e68ffe07.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/75528de3-719a-461e-89f8-2db8d70d318d.npy, Shape: (156, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/87f8d5e2-837e-44d9-b2fd-c67a1574ee3e.npy, Shape: (142, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/c5b87769-c36c-4644-a9c2-dff0b10b317a.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/6a5df173-f866-4e03-b14a-3bd963ed8649.npy, Shape: (254, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/2d9bd6cd-98ce-4ca2-a56a-4d61657ed935.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/f05a7799-926b-41db-8b22-26acf0a2b7ed.npy, Shape: (210, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/5d3a03be-8f15-4c0d-9bdb-1fb8f38076cf.npy, Shape: (270, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/d54baae8-e42f-4065-b6c1-27e4a8075a8f.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/0b8d6666-d57a-4bf2-a0f0-fb6de7f69a90.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/e086083a-ef9b-4d33-b81a-9f61b7810e07.npy, Shape: (134, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/fb7b73db-cf2a-4265-8d83-97942dadd241.npy, Shape: (276, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/dc3cc96e-37d8-48f9-b033-6b75cc9de47b.npy, Shape: (164, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/4eb8fabb-e506-4de9-858d-3828f8b9c69a.npy, Shape: (284, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/19227eda-1338-42b5-afab-130afd8233e3.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/8657d9d4-1ff5-4dd2-be08-256da0d647ef.npy, Shape: (142, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/699b9535-afd3-4229-989d-34b1899ff3b8.npy, Shape: (164, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/062bbee4-bcaa-4fc1-ba19-3784ec31309c.npy, Shape: (194, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/8eb1b8b2-08bf-40ca-b567-2c9c6fcb67c1.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/3c5dd9df-a0cf-484d-9f47-c1343c3b29db.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/8a718ebd-e9a2-40e3-9620-f13b857910aa.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/58ad4e7f-bbf2-4903-a3a1-89642cddb719.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/8e376cf1-48dd-4cd6-b193-b3fd0dd60280.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/cd50ee6b-d468-4560-b40c-40d487fcde7e.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/9671c795-1071-4461-995f-f11f6fe0282a.npy, Shape: (232, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/ea1032b8-26d3-4cd8-afae-ac44572a438f.npy, Shape: (270, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/c7e26af7-fc55-4802-9453-196295598a68.npy, Shape: (510, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/4d644fa2-4325-4d4c-8600-4f737834fd1e.npy, Shape: (360, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/7cee92ec-a495-498b-b8b2-de1b352c45a4.npy, Shape: (194, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/a2667234-428d-4c3e-a422-9412cbc17733.npy, Shape: (780, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/6c8624be-6b19-47a2-be47-6f801f7ab164.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/5ffe0302-c55e-4dc0-84fc-122df02bb2fa.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/9e034b69-a477-46e6-a8ec-6efd7c263af0.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/276690f9-ab06-48d0-aa8d-bc3e5478fb13.npy, Shape: (104, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/e52a43c4-c3b8-4918-9271-308cd9eca059.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/6d736267-5685-4048-a535-964394266256.npy, Shape: (238, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/4c39d90c-4d71-41d7-9779-0b830d4fb1e0.npy, Shape: (194, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/b7f8630d-dc90-4135-bdf5-5a089489bef8.npy, Shape: (352, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/09ad9f9e-338e-4570-93cf-80d772088fbe.npy, Shape: (284, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/20a115af-abae-4831-b62e-a41379c68273.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/82c5c5a4-3101-4ad8-b417-ec599b926db1.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/3b646e0b-989c-4fda-b84e-3c9de2399a5a.npy, Shape: (90, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/5b8ec090-f772-4b12-bee4-d6e765ebe725.npy, Shape: (90, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/a7aa14d4-c451-4968-8585-89281f99a4ec.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/ecc891d9-f253-450b-b850-274d8c0e1457.npy, Shape: (120, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/06b959ab-9f60-48c7-87f8-d22e7e5db4a2.npy, Shape: (60, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/568eee02-254f-4cd6-9410-eb19585e544f.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/2ec5052c-c265-4edb-aa46-6460c217fcf2.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/9b1dfc18-e8b4-4996-9177-0660760dac57.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/3f6b4114-b4fb-4ee8-a8b8-2f73e53af0ea.npy, Shape: (142, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/b2412571-3c07-4002-beff-b9715ef5066f.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/70b02379-4be3-41b7-9e56-047433b79547.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/5747fef5-f2a4-47d2-a58a-96071c709ea0.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/18ec8b70-5dfa-4377-84b9-048155001141.npy, Shape: (104, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/78b36dd2-edd6-46b0-87eb-3a282f87015e.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/92a63b52-f2fc-4f48-b9bf-22c176bb5a25.npy, Shape: (126, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/c48de1f3-c7de-4656-be3b-bb3fd96356f4.npy, Shape: (270, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/0c41b908-6643-4ed6-a23b-d37bfc1eb76c.npy, Shape: (360, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/b699ffe3-d98b-48a3-8b9c-eced13c18c63.npy, Shape: (178, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/bd4876a7-3932-446c-b605-633bdb276811.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/44d7e12c-568e-427e-bdcd-2f8354e7dea6.npy, Shape: (480, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/06512d85-40a7-4951-9f3b-802893fbff12.npy, Shape: (82, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/32b3c3bb-17a6-4692-ab2c-322c640fd961.npy, Shape: (142, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/b9940849-d624-4f21-bbe2-1168b633c3b7.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/7db0ecff-018e-41ea-8136-78a73cc1c9e7.npy, Shape: (254, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/a3e578aa-ba6a-4f81-8a01-10597a64ed19.npy, Shape: (360, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/97b7c9dd-74b3-4051-a2a8-a66b8bd5418b.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/ead027d3-45d2-4366-896b-d135371be543.npy, Shape: (164, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/cb9f652c-3dd8-4d5b-a3fa-9664c5d9d1b7.npy, Shape: (540, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/6c56ef99-088c-4c99-9047-e259e85cbe30.npy, Shape: (60, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/6b50de23-fd3b-4772-8c5b-f00bbefdaa76.npy, Shape: (246, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/cd4b25a2-5306-4e59-a301-c7fa53794e20.npy, Shape: (194, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/2cbfa1f7-1e9c-468f-b876-f100bae407ce.npy, Shape: (262, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/6655605a-fc19-45c2-8972-0d6e598f51a3.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/40b2d516-8879-4910-b9bd-edbc85a80c67.npy, Shape: (360, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/4a1cd1d2-fc52-4bbf-bf42-11340dc4f580.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/a5e6c796-e253-4ce9-bb05-6dceb203836a.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/12dea207-e803-4a5a-b46c-fb54fa182fcb.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/824ecb50-b77b-4bb3-bf79-98f87a51c42f.npy, Shape: (360, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/a3b69458-7d2d-462d-9657-7ed64fba79fa.npy, Shape: (142, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/950ed77e-f1dc-4d40-a7f4-0e0c1ef1c1b0.npy, Shape: (210, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/58f1e041-95a9-4c08-a35c-dbcba8e9627a.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/388cb2df-dd8b-4069-b123-4fc2efc9abb1.npy, Shape: (202, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/241c8f63-34f8-4fa8-8ac3-e1c2ba75fbb4.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/1bf11e6c-a918-4e00-8850-14f554af1d4c.npy, Shape: (360, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/55dedc1a-5025-4b14-aa4e-327b1acb279a.npy, Shape: (112, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/3a2046fd-a419-4fcb-bcf8-427d9b62270b.npy, Shape: (120, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/32539e4d-04f6-4e17-8afc-a02657c01968.npy, Shape: (178, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/8b8c0f78-100e-4477-b6a3-1e464d3e9d08.npy, Shape: (480, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/789122e5-ff0a-44bf-86d0-8d195555af08.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/6b752431-6011-49b8-a3fc-84c8e705070e.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/2d9a32b2-8a95-48a9-ae43-01c83a9bbf36.npy, Shape: (120, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/45ae417f-6895-4245-b35e-c00f06e99b28.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/8c731559-f1a2-4611-b85c-dcfe991ee85d.npy, Shape: (262, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/e28d0073-737e-497a-9794-0b1c8ccb0c1d.npy, Shape: (510, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/6b678d0e-3cb3-4437-a421-b4a5f032939f.npy, Shape: (88, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/7cafd774-1088-443f-9b67-15956cd72b70.npy, Shape: (194, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/0f388736-f574-449e-9ab7-4cfa531a6b51.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/260e367a-a54c-40fb-a2b9-3ac7364d5703.npy, Shape: (360, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/41b95834-ad4e-444e-a981-65f8d2855db5.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/ef56a73f-20d5-4efa-b479-a716fb670faa.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/8801f476-7471-4286-b175-bbd66710283a.npy, Shape: (164, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/30a79e9b-931f-45c9-bc06-71e7fa3f21ee.npy, Shape: (270, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/94e7548e-2776-4d28-bcf1-bc44a7624646.npy, Shape: (142, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/69efec09-8e14-43fc-951b-1d665b1bc84e.npy, Shape: (186, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/6af1d394-4b5f-45d4-8cff-5d02c1fa4d0d.npy, Shape: (120, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/62430b71-8476-44fb-b23e-b3329c628ea6.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/96163dcf-243f-4813-8dcc-340ef5304059.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/54941413-97cb-463f-94c0-bd8331df141d.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/3f3ec9c9-4b49-4b1b-b916-454ba621d827.npy, Shape: (246, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/252a7231-cf00-47c2-af1f-d7ea7d1db8bd.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/848c04d1-c5bf-45ae-a5c1-62a3c8f97365.npy, Shape: (120, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/0db072f3-d123-44cb-9edf-23dbdad3ccac.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/a11d9a13-74c6-4671-a1ca-51db7465552b.npy, Shape: (262, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/108525ef-8fac-48cb-8e36-892ff073a1e2.npy, Shape: (330, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/11b727b1-e4a6-46bc-92b4-6689cf2ca09e.npy, Shape: (164, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/cfbf3f06-5190-433a-91e2-bf8c2332ef0c.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/ed203370-f3ad-4861-8034-f7bc2b0afaf5.npy, Shape: (90, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/64fed362-967f-4127-835c-53ea23fe39f3.npy, Shape: (120, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/1ab08478-1958-4366-87b1-9b48c3ccc541.npy, Shape: (382, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/a3d195d1-ca64-4c4d-965d-86f7af28b4e8.npy, Shape: (142, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/a2a733d8-ab8e-4e0a-82cc-4f29a126791e.npy, Shape: (90, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/7311a172-0ba4-4d7f-a473-52a42b9e81a4.npy, Shape: (300, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/423792cd-9efa-4a4f-b3e7-747d6fb7f1f8.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/c265088b-1094-46ae-88d6-e6f664892327.npy, Shape: (300, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/3f07519f-1d30-4665-bd3c-9ae199403366.npy, Shape: (88, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/aece7fd7-9690-42f9-a87f-2b205c1f5aa4.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/00d5a64d-7e78-4662-9f00-c2a7c69cace8.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/0ba7c96d-81d2-48a5-b842-e437a84b4af7.npy, Shape: (66, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/1e57e1f5-d934-4a30-811a-7f56ba583b8e.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/93def8bf-d9e9-4855-a6b9-30cb1b9f96f1.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/51c50bc7-c0fa-4204-bf87-c1dbdef6022a.npy, Shape: (186, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/883beada-7ccb-43c5-b944-e4603fc3f5f9.npy, Shape: (134, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/4b913aca-07c2-40c5-b099-da4b895994dc.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/28c02b8c-ebf8-413c-83b2-49ba2f46c2c2.npy, Shape: (224, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/4fcddec7-cecf-44c0-a4e4-ee15c812ca85.npy, Shape: (360, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/3bc02a66-c497-4ab7-9d4c-6c847efa6425.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/89c1ddc4-b25d-4b5d-81b4-571fc8e1ff09.npy, Shape: (164, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/7d6d0986-4228-45f5-8b39-acd82ee77f78.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/5a6ce7f8-a7b2-4a85-8a44-0b6abfddffc4.npy, Shape: (104, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/9ec457c5-91c6-4e28-a36a-2ab463b03f29.npy, Shape: (284, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/7afcb718-d439-4222-a880-85e33dc6648a.npy, Shape: (134, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/7af02f13-832a-45ea-b709-3d0d701b6003.npy, Shape: (270, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/63d3a010-9b8c-4181-9ca6-673ba68b682a.npy, Shape: (300, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/392991b5-f24b-41bd-a690-6b998c5b8f25.npy, Shape: (120, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/a7c2c1e3-25ad-49a3-81f3-73c9830bfd03.npy, Shape: (540, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/08773a0f-8905-4c68-9d9b-321d2a8ef6b2.npy, Shape: (118, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/545870a7-5793-4904-9885-fe30f31a20fc.npy, Shape: (164, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/7fd1e388-5a08-450a-9c55-8d92e5a6cd83.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/be27f2ce-8cfb-46c7-90c8-92abeda9cb39.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/7d6e99a8-45c1-4328-b070-fc4e90fed8bc.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/afe5f180-6c04-4191-949a-b24b34351a72.npy, Shape: (142, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/4ef07058-9477-4216-b677-bd3e6a906c7e.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/46a329a6-8947-4252-9eef-09548b2a3023.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/29727134-fa50-4e0e-847d-24ea334b0b4f.npy, Shape: (540, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/0b552512-3809-416f-9d33-d734abdc62fa.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/fa818724-4f54-4da8-b44f-76b024c781e6.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/357ccf06-9ac7-4d6e-a895-e4b0ef21bfe6.npy, Shape: (360, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/d454d3c6-efd5-4d53-bd6b-82338842a2b2.npy, Shape: (480, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/b2a75b06-bec7-4f92-8d7e-d0a2e523e975.npy, Shape: (148, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/046e6fab-6a93-4dec-b88b-5511afd7fe62.npy, Shape: (142, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/9d5cf73c-dd2f-4e2d-a8a9-82d81fd11e51.npy, Shape: (262, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/ca167fa6-c6df-4378-a588-68b2e019b2cb.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/a51421b9-b70f-479a-ad28-07cad0db8454.npy, Shape: (360, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/9a879896-1b9f-4bea-9057-63bf021bc76d.npy, Shape: (96, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/9a0f9d6d-6c87-4a2d-b6d5-f7fa2a5a37ad.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/c4466a07-d1ac-4e3e-87de-1f35c63725b0.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/5ea07f42-2ec0-484a-a45c-cb915912601d.npy, Shape: (232, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/80fdbb32-cb82-411c-8fbf-d58c1b5e6d51.npy, Shape: (300, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/95be7df6-317d-4059-9ad6-8ba087ea774d.npy, Shape: (164, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/9d37c401-0345-4518-b632-195483cc1371.npy, Shape: (112, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/15c51b29-9265-4ec1-9e30-60a160f252e6.npy, Shape: (140, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/605fc38d-edf5-4350-8d50-b270e95ecc16.npy, Shape: (120, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/086d9421-afb3-423d-8170-04ae2fcc3948.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/49ab74ee-0433-4ec2-8cf1-5331034918f9.npy, Shape: (142, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/2bc76da3-c604-433f-9d1b-e92306e34304.npy, Shape: (90, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/59423d0e-db64-4673-a197-97c5304ff813.npy, Shape: (120, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/a00dba3f-bf0c-43fb-a816-124555a3fea8.npy, Shape: (480, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/32993929-c9a4-4e84-846a-a16f8abfb3e2.npy, Shape: (480, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/4a9bdd2c-f92f-48c3-a72a-ef40f6b00618.npy, Shape: (322, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/e50fdbad-6817-4439-b7c0-97ae63bac3cc.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/5e3d853e-38c4-44e4-8eb5-bceef55602ee.npy, Shape: (104, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/94c60cb1-37be-40b1-9417-c187c7d00877.npy, Shape: (600, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/01bd1017-7748-4e0b-bf57-d9012563695a.npy, Shape: (600, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/9fd0b386-9bda-4da5-ac7e-25fd8e6000d6.npy, Shape: (254, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/d3a71d37-ca39-47a8-b126-40e495b64267.npy, Shape: (570, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/7aef186a-3d4b-48e0-b41c-6cc29f6bd643.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/8eb0c569-ac6e-4452-a22d-8eedfa404faa.npy, Shape: (202, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/64e1baa3-2fc8-4879-93f3-c01c6cf4139c.npy, Shape: (238, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/05c8e8e2-7459-48ef-afc3-0d1b5194cb25.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/4114a1f5-b186-437f-954a-cd020f84ddf8.npy, Shape: (120, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/c9b113f3-3dcb-488f-a90c-63e4a486a609.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/4cbfd7c2-5f34-468d-95ba-50871281155e.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/0c532a7e-f904-49a6-b420-b63feb4e1e15.npy, Shape: (300, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/e2a1add5-4438-4ce9-a6c3-24731f58e99d.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/5bd68e52-2630-4bde-99a6-99bede4b6de0.npy, Shape: (164, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/959a8c82-fd17-44a5-911f-cd5cdc3b773a.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/46226272-b22d-4ac5-aa51-99f00b8570c7.npy, Shape: (510, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/43cf172a-9fd9-41a5-a83b-1f17a0f1ff61.npy, Shape: (112, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/a654f714-3420-4a85-abb2-51326c3c55fe.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/7d34064d-1ad3-4e4d-afdd-2099bcdd8952.npy, Shape: (480, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/60cd134b-e8b3-4ead-84ca-a02cc7c46c20.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/2a5e9f5c-5296-4a08-8633-ad43868fea6b.npy, Shape: (164, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/d6d81bbb-c92a-4a28-933c-4ae5b90f6232.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/fd7545b6-acb7-47b2-94ed-4b6c8f9b9714.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/2bab6951-1843-4503-90eb-d3f3cc8b471f.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/a8480a14-3542-4a4f-bb5a-877b3dbce03f.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/58a7730f-04ba-407a-b80d-b277143dd37d.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/3b3d1027-51ea-4502-b60d-6960b3d4d2d4.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/7df07116-21cc-44ca-87a1-061e3762d491.npy, Shape: (164, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/638082ab-6b09-45e3-bb68-cfaa3fc0408a.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/7d436d64-e4c5-4a6c-a255-86dd338a8c16.npy, Shape: (120, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/2fd6b648-695c-4acf-849b-9182456e3a97.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/5c14dd9e-130b-4405-ad4a-bee1726a7a68.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/b629c6f9-8d83-43b5-8845-1447c850b90b.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/c1d317b2-638a-45d1-9800-c62f266bed77.npy, Shape: (232, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/6431472b-5450-4dda-b563-ec17908fded2.npy, Shape: (156, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/1277cf3d-b448-4041-8226-1ac216112e72.npy, Shape: (224, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/43bbe34d-77c1-4022-b31c-0ef83d002049.npy, Shape: (120, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/98ef8f1a-17c0-4d59-81dc-4dbb5091ca97.npy, Shape: (690, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/78601b52-4224-4926-8aef-a6c6328b5944.npy, Shape: (330, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/88e343f7-71e6-460b-997b-67020023567d.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/5442ec06-07e8-4523-b579-e7ce627df75b.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/2fbc0d39-970f-4d11-801e-a0ba184af6ed.npy, Shape: (112, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/d57e4d93-1403-46c9-bf67-556b8118c706.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/77120d03-74ee-4190-933a-0f40528906ff.npy, Shape: (202, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/bd3f7c77-f5c8-4c99-b028-c6978f622f26.npy, Shape: (142, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/1d39094f-7d92-47c0-9dc2-f6bace8bfd8b.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/1e842859-77da-4601-86b1-a2a2942003dd.npy, Shape: (202, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/7857ca70-4ec3-49e3-ace8-db5d72e549c8.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/a327365d-c9fe-4888-be52-3d5ebea5fae0.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/02d9a67f-cd75-4880-9e41-08b9369e5ded(1).npy, Shape: (202, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/07794882-8538-42f4-a06d-4c147a7b377b.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/e9977599-e366-4cc7-87bf-8dd7a7f2cff1.npy, Shape: (90, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/6050937a-cfd0-4fb2-a6f1-e56e4ec4db94.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/2d350c6d-e025-45f1-a8e6-80552c791c46.npy, Shape: (90, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/ad7cc305-aa85-4ba0-8faa-30e92bd17935.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/aa3525bd-262b-4349-b4b2-41ae8058a809.npy, Shape: (300, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/42a362bd-7c23-4380-a042-a992f7fb75c9.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/5b2da383-0157-4877-bee3-c43ae6116348.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/8c8fd994-6c2c-4430-88cf-3e642279e294.npy, Shape: (118, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/5cd233cf-6402-433c-88e1-505b715340de.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/7d461c0a-9704-4bd6-b2e1-ce9202fd5442.npy, Shape: (330, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/8e290f43-5b2d-4cc9-8f1e-fbf0db5eee71.npy, Shape: (210, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/d4414322-a206-465b-adec-5e105ba0a9fe.npy, Shape: (74, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/b534a2bd-6236-4f27-80a2-7aeb7f471838.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/d90f6d6e-f1bf-4009-892a-dc457535bc4e.npy, Shape: (570, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/a95479e6-25e4-4f40-9865-bdc00f640f2e.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/71481dc5-8709-45c4-970b-0aeb0b2cbbf9.npy, Shape: (300, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/aec024cb-5fd0-4ba8-a1ec-a1a63f13f650.npy, Shape: (210, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/beb350a4-280f-4a72-a0f1-db41ac394958.npy, Shape: (202, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/c53b0315-5f84-499d-aba9-1a3edbcd5e85.npy, Shape: (570, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/2b4d25e3-309b-4618-9b7b-486db9d8f2a6.npy, Shape: (270, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/004ed8d4-5be9-4963-bdb3-8aace317cd74.npy, Shape: (82, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/f480e49c-ac72-4cda-a0c3-7aa3c48f592b.npy, Shape: (90, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/7612fbfb-910c-440b-9093-4d09a2c8db6a.npy, Shape: (60, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/2b045312-775d-4005-92ad-760f39e29637.npy, Shape: (300, 1, 512)
# File: /kaggle/working/VGG16_test_features/frontal_view/VGG16_features/73a84ac9-549c-4288-8614-88ae9a443603.npy, Shape: (142, 1, 512)
#
# View: left_view
# File: /kaggle/working/VGG16_test_features/left_view/bd0e6ef3-0ee3-42d2-ba89-87e27f31da87.npy, Shape: (360, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/b8cf26e4-7329-4cfa-aca7-00bd40975ff0.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/60ad70f9-ecde-4f47-87ec-41bbc1221d94.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/7d43bedb-13c3-4b9d-9050-f1652b110a1e.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/dec19835-0fb4-4887-8178-19df3b497153.npy, Shape: (254, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/ab0832d7-1a2b-43a6-bec7-10cb25ca7983.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/66e56d2d-d4c4-42d2-b5b7-eb141fbd097f.npy, Shape: (156, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/02d9a67f-cd75-4880-9e41-08b9369e5ded.npy, Shape: (202, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/30b2c119-7f65-4791-afc4-93bbd8a2592f.npy, Shape: (300, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/cab48330-ac2b-4218-b05c-d0806e735bd5.npy, Shape: (156, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/13d1aac7-01e8-4d8f-be04-6b9bf1d78c38.npy, Shape: (254, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/bf900a43-4579-4031-b2e5-0fa24c7e00d4.npy, Shape: (142, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/5715a0a6-7fa2-4b5b-8f42-d43fcab9729a.npy, Shape: (202, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/acc2b4ae-1de1-4875-b4b8-3731eab75219.npy, Shape: (510, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/08fad321-94d6-4a5d-9203-4b76e0e26589.npy, Shape: (270, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/dc6efa69-6946-4e2b-9de4-288cbf3c20a6.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/2589beef-c7bc-4aff-a0f7-834cf661ce8b.npy, Shape: (300, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/35c62f85-9117-49e7-89d3-fa381057ae8d.npy, Shape: (480, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/ad26369a-749b-4222-a86f-055ea43d9291.npy, Shape: (104, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/505b42c8-9c46-4955-936f-16bfac5b8830.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/ac34341c-f835-499e-8706-b143adbabc5e.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/3be87140-9bcf-4eff-91d4-1795e3e5802d.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/9aaf8611-a2bc-4f1d-97c5-10e469d76456.npy, Shape: (194, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/6e117e55-f0dc-4305-834c-a5c8b29c7d3f.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/9fff9170-316b-468e-9ebd-1b3070fade5b.npy, Shape: (194, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/d3f77ea2-8db9-458b-b33a-e8024c77f566.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/5b2c6d24-4b3d-46ff-adef-b732508b3bb5.npy, Shape: (232, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/3a687a03-9d61-4741-9ef3-c54986769657.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/18148502-eb8a-49a1-a95d-76a02852a9cc.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/4a9bd7f9-da7d-4f31-a846-b732853d7aa4.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/fa1b0774-22d2-4411-ba35-734c2d7467c5.npy, Shape: (210, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/fc9b8169-9f71-446b-bb0c-cd05283e61e5.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/33993e5f-d42e-469a-bc34-dfb5fdf4edf6.npy, Shape: (120, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/8e069130-c58e-4778-b53b-b662556b54ed.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/6613d10d-3f50-4a79-a013-cc5da63f95b1.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/1d98d9d5-ad45-46ff-b3c2-f22546b2a7e3.npy, Shape: (480, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/2eac9b90-e267-4d92-852b-79b65002828e.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/13908178-9a4e-4862-ab9d-25ada8717d2c.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/41a79829-f926-4f7d-9d7a-630f6cace179.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/f3dc043b-39fb-438d-b170-e4fc7413a9ec.npy, Shape: (330, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/ed875a76-8c9a-4188-9a9b-c4a2c681b829.npy, Shape: (90, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/9407075f-f54b-4aa8-adbb-2f96e68ffe07.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/75528de3-719a-461e-89f8-2db8d70d318d.npy, Shape: (156, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/87f8d5e2-837e-44d9-b2fd-c67a1574ee3e.npy, Shape: (142, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/c5b87769-c36c-4644-a9c2-dff0b10b317a.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/6a5df173-f866-4e03-b14a-3bd963ed8649.npy, Shape: (254, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/2d9bd6cd-98ce-4ca2-a56a-4d61657ed935.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/f05a7799-926b-41db-8b22-26acf0a2b7ed.npy, Shape: (210, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/5d3a03be-8f15-4c0d-9bdb-1fb8f38076cf.npy, Shape: (270, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/d54baae8-e42f-4065-b6c1-27e4a8075a8f.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/0b8d6666-d57a-4bf2-a0f0-fb6de7f69a90.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/e086083a-ef9b-4d33-b81a-9f61b7810e07.npy, Shape: (134, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/fb7b73db-cf2a-4265-8d83-97942dadd241.npy, Shape: (276, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/dc3cc96e-37d8-48f9-b033-6b75cc9de47b.npy, Shape: (164, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/4eb8fabb-e506-4de9-858d-3828f8b9c69a.npy, Shape: (284, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/19227eda-1338-42b5-afab-130afd8233e3.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/8657d9d4-1ff5-4dd2-be08-256da0d647ef.npy, Shape: (142, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/699b9535-afd3-4229-989d-34b1899ff3b8.npy, Shape: (164, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/062bbee4-bcaa-4fc1-ba19-3784ec31309c.npy, Shape: (194, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/8eb1b8b2-08bf-40ca-b567-2c9c6fcb67c1.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/3c5dd9df-a0cf-484d-9f47-c1343c3b29db.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/8a718ebd-e9a2-40e3-9620-f13b857910aa.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/58ad4e7f-bbf2-4903-a3a1-89642cddb719.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/8e376cf1-48dd-4cd6-b193-b3fd0dd60280.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/cd50ee6b-d468-4560-b40c-40d487fcde7e.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/9671c795-1071-4461-995f-f11f6fe0282a.npy, Shape: (232, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/ea1032b8-26d3-4cd8-afae-ac44572a438f.npy, Shape: (270, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/c7e26af7-fc55-4802-9453-196295598a68.npy, Shape: (510, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/4d644fa2-4325-4d4c-8600-4f737834fd1e.npy, Shape: (360, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/7cee92ec-a495-498b-b8b2-de1b352c45a4.npy, Shape: (194, 1, 512)
# File: /kaggle/working/VGG16_test_features/left_view/a2667234-428d-4c3e-a422-9412cbc17733.npy, Shape: (780, 1, 512)
# ...
# File: /kaggle/working/VGG16_test_features/right_view/a3d195d1-ca64-4c4d-965d-86f7af28b4e8.npy, Shape: (142, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/a2a733d8-ab8e-4e0a-82cc-4f29a126791e.npy, Shape: (90, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/7311a172-0ba4-4d7f-a473-52a42b9e81a4.npy, Shape: (300, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/423792cd-9efa-4a4f-b3e7-747d6fb7f1f8.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/c265088b-1094-46ae-88d6-e6f664892327.npy, Shape: (300, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/3f07519f-1d30-4665-bd3c-9ae199403366.npy, Shape: (88, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/aece7fd7-9690-42f9-a87f-2b205c1f5aa4.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/00d5a64d-7e78-4662-9f00-c2a7c69cace8.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/0ba7c96d-81d2-48a5-b842-e437a84b4af7.npy, Shape: (66, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/1e57e1f5-d934-4a30-811a-7f56ba583b8e.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/93def8bf-d9e9-4855-a6b9-30cb1b9f96f1.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/51c50bc7-c0fa-4204-bf87-c1dbdef6022a.npy, Shape: (186, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/883beada-7ccb-43c5-b944-e4603fc3f5f9.npy, Shape: (134, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/4b913aca-07c2-40c5-b099-da4b895994dc.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/28c02b8c-ebf8-413c-83b2-49ba2f46c2c2.npy, Shape: (224, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/4fcddec7-cecf-44c0-a4e4-ee15c812ca85.npy, Shape: (360, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/3bc02a66-c497-4ab7-9d4c-6c847efa6425.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/89c1ddc4-b25d-4b5d-81b4-571fc8e1ff09.npy, Shape: (164, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/7d6d0986-4228-45f5-8b39-acd82ee77f78.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/5a6ce7f8-a7b2-4a85-8a44-0b6abfddffc4.npy, Shape: (104, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/9ec457c5-91c6-4e28-a36a-2ab463b03f29.npy, Shape: (284, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/7afcb718-d439-4222-a880-85e33dc6648a.npy, Shape: (134, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/7af02f13-832a-45ea-b709-3d0d701b6003.npy, Shape: (270, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/63d3a010-9b8c-4181-9ca6-673ba68b682a.npy, Shape: (300, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/392991b5-f24b-41bd-a690-6b998c5b8f25.npy, Shape: (120, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/a7c2c1e3-25ad-49a3-81f3-73c9830bfd03.npy, Shape: (540, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/08773a0f-8905-4c68-9d9b-321d2a8ef6b2.npy, Shape: (118, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/545870a7-5793-4904-9885-fe30f31a20fc.npy, Shape: (164, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/7fd1e388-5a08-450a-9c55-8d92e5a6cd83.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/be27f2ce-8cfb-46c7-90c8-92abeda9cb39.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/7d6e99a8-45c1-4328-b070-fc4e90fed8bc.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/afe5f180-6c04-4191-949a-b24b34351a72.npy, Shape: (142, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/4ef07058-9477-4216-b677-bd3e6a906c7e.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/46a329a6-8947-4252-9eef-09548b2a3023.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/29727134-fa50-4e0e-847d-24ea334b0b4f.npy, Shape: (540, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/0b552512-3809-416f-9d33-d734abdc62fa.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/fa818724-4f54-4da8-b44f-76b024c781e6.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/357ccf06-9ac7-4d6e-a895-e4b0ef21bfe6.npy, Shape: (360, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/d454d3c6-efd5-4d53-bd6b-82338842a2b2.npy, Shape: (480, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/b2a75b06-bec7-4f92-8d7e-d0a2e523e975.npy, Shape: (148, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/046e6fab-6a93-4dec-b88b-5511afd7fe62.npy, Shape: (142, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/9d5cf73c-dd2f-4e2d-a8a9-82d81fd11e51.npy, Shape: (262, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/ca167fa6-c6df-4378-a588-68b2e019b2cb.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/a51421b9-b70f-479a-ad28-07cad0db8454.npy, Shape: (360, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/9a879896-1b9f-4bea-9057-63bf021bc76d.npy, Shape: (96, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/9a0f9d6d-6c87-4a2d-b6d5-f7fa2a5a37ad.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/c4466a07-d1ac-4e3e-87de-1f35c63725b0.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/5ea07f42-2ec0-484a-a45c-cb915912601d.npy, Shape: (232, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/80fdbb32-cb82-411c-8fbf-d58c1b5e6d51.npy, Shape: (300, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/95be7df6-317d-4059-9ad6-8ba087ea774d.npy, Shape: (164, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/9d37c401-0345-4518-b632-195483cc1371.npy, Shape: (112, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/15c51b29-9265-4ec1-9e30-60a160f252e6.npy, Shape: (140, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/605fc38d-edf5-4350-8d50-b270e95ecc16.npy, Shape: (120, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/086d9421-afb3-423d-8170-04ae2fcc3948.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/49ab74ee-0433-4ec2-8cf1-5331034918f9.npy, Shape: (142, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/2bc76da3-c604-433f-9d1b-e92306e34304.npy, Shape: (90, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/59423d0e-db64-4673-a197-97c5304ff813.npy, Shape: (120, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/a00dba3f-bf0c-43fb-a816-124555a3fea8.npy, Shape: (480, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/32993929-c9a4-4e84-846a-a16f8abfb3e2.npy, Shape: (480, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/4a9bdd2c-f92f-48c3-a72a-ef40f6b00618.npy, Shape: (322, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/e50fdbad-6817-4439-b7c0-97ae63bac3cc.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/5e3d853e-38c4-44e4-8eb5-bceef55602ee.npy, Shape: (104, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/94c60cb1-37be-40b1-9417-c187c7d00877.npy, Shape: (600, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/01bd1017-7748-4e0b-bf57-d9012563695a.npy, Shape: (600, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/9fd0b386-9bda-4da5-ac7e-25fd8e6000d6.npy, Shape: (254, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/d3a71d37-ca39-47a8-b126-40e495b64267.npy, Shape: (570, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/7aef186a-3d4b-48e0-b41c-6cc29f6bd643.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/8eb0c569-ac6e-4452-a22d-8eedfa404faa.npy, Shape: (202, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/64e1baa3-2fc8-4879-93f3-c01c6cf4139c.npy, Shape: (238, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/05c8e8e2-7459-48ef-afc3-0d1b5194cb25.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/4114a1f5-b186-437f-954a-cd020f84ddf8.npy, Shape: (120, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/c9b113f3-3dcb-488f-a90c-63e4a486a609.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/4cbfd7c2-5f34-468d-95ba-50871281155e.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/0c532a7e-f904-49a6-b420-b63feb4e1e15.npy, Shape: (300, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/e2a1add5-4438-4ce9-a6c3-24731f58e99d.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/5bd68e52-2630-4bde-99a6-99bede4b6de0.npy, Shape: (164, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/959a8c82-fd17-44a5-911f-cd5cdc3b773a.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/46226272-b22d-4ac5-aa51-99f00b8570c7.npy, Shape: (510, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/43cf172a-9fd9-41a5-a83b-1f17a0f1ff61.npy, Shape: (112, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/a654f714-3420-4a85-abb2-51326c3c55fe.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/7d34064d-1ad3-4e4d-afdd-2099bcdd8952.npy, Shape: (480, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/60cd134b-e8b3-4ead-84ca-a02cc7c46c20.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/2a5e9f5c-5296-4a08-8633-ad43868fea6b.npy, Shape: (164, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/d6d81bbb-c92a-4a28-933c-4ae5b90f6232.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/fd7545b6-acb7-47b2-94ed-4b6c8f9b9714.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/2bab6951-1843-4503-90eb-d3f3cc8b471f.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/a8480a14-3542-4a4f-bb5a-877b3dbce03f.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/58a7730f-04ba-407a-b80d-b277143dd37d.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/3b3d1027-51ea-4502-b60d-6960b3d4d2d4.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/7df07116-21cc-44ca-87a1-061e3762d491.npy, Shape: (164, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/638082ab-6b09-45e3-bb68-cfaa3fc0408a.npy, Shape: (420, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/7d436d64-e4c5-4a6c-a255-86dd338a8c16.npy, Shape: (120, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/2fd6b648-695c-4acf-849b-9182456e3a97.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/5c14dd9e-130b-4405-ad4a-bee1726a7a68.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/b629c6f9-8d83-43b5-8845-1447c850b90b.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/c1d317b2-638a-45d1-9800-c62f266bed77.npy, Shape: (232, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/6431472b-5450-4dda-b563-ec17908fded2.npy, Shape: (156, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/1277cf3d-b448-4041-8226-1ac216112e72.npy, Shape: (224, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/43bbe34d-77c1-4022-b31c-0ef83d002049.npy, Shape: (120, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/98ef8f1a-17c0-4d59-81dc-4dbb5091ca97.npy, Shape: (690, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/78601b52-4224-4926-8aef-a6c6328b5944.npy, Shape: (330, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/88e343f7-71e6-460b-997b-67020023567d.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/5442ec06-07e8-4523-b579-e7ce627df75b.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/2fbc0d39-970f-4d11-801e-a0ba184af6ed.npy, Shape: (112, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/d57e4d93-1403-46c9-bf67-556b8118c706.npy, Shape: (180, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/77120d03-74ee-4190-933a-0f40528906ff.npy, Shape: (202, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/bd3f7c77-f5c8-4c99-b028-c6978f622f26.npy, Shape: (142, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/1d39094f-7d92-47c0-9dc2-f6bace8bfd8b.npy, Shape: (172, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/1e842859-77da-4601-86b1-a2a2942003dd.npy, Shape: (202, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/7857ca70-4ec3-49e3-ace8-db5d72e549c8.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/a327365d-c9fe-4888-be52-3d5ebea5fae0.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/02d9a67f-cd75-4880-9e41-08b9369e5ded(1).npy, Shape: (202, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/07794882-8538-42f4-a06d-4c147a7b377b.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/e9977599-e366-4cc7-87bf-8dd7a7f2cff1.npy, Shape: (90, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/6050937a-cfd0-4fb2-a6f1-e56e4ec4db94.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/2d350c6d-e025-45f1-a8e6-80552c791c46.npy, Shape: (90, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/ad7cc305-aa85-4ba0-8faa-30e92bd17935.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/aa3525bd-262b-4349-b4b2-41ae8058a809.npy, Shape: (300, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/42a362bd-7c23-4380-a042-a992f7fb75c9.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/5b2da383-0157-4877-bee3-c43ae6116348.npy, Shape: (150, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/8c8fd994-6c2c-4430-88cf-3e642279e294.npy, Shape: (118, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/5cd233cf-6402-433c-88e1-505b715340de.npy, Shape: (450, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/7d461c0a-9704-4bd6-b2e1-ce9202fd5442.npy, Shape: (330, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/8e290f43-5b2d-4cc9-8f1e-fbf0db5eee71.npy, Shape: (210, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/d4414322-a206-465b-adec-5e105ba0a9fe.npy, Shape: (74, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/b534a2bd-6236-4f27-80a2-7aeb7f471838.npy, Shape: (390, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/d90f6d6e-f1bf-4009-892a-dc457535bc4e.npy, Shape: (570, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/a95479e6-25e4-4f40-9865-bdc00f640f2e.npy, Shape: (240, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/71481dc5-8709-45c4-970b-0aeb0b2cbbf9.npy, Shape: (300, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/aec024cb-5fd0-4ba8-a1ec-a1a63f13f650.npy, Shape: (210, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/beb350a4-280f-4a72-a0f1-db41ac394958.npy, Shape: (202, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/c53b0315-5f84-499d-aba9-1a3edbcd5e85.npy, Shape: (570, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/2b4d25e3-309b-4618-9b7b-486db9d8f2a6.npy, Shape: (270, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/004ed8d4-5be9-4963-bdb3-8aace317cd74.npy, Shape: (82, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/f480e49c-ac72-4cda-a0c3-7aa3c48f592b.npy, Shape: (90, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/7612fbfb-910c-440b-9093-4d09a2c8db6a.npy, Shape: (60, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/2b045312-775d-4005-92ad-760f39e29637.npy, Shape: (300, 1, 512)
# File: /kaggle/working/VGG16_test_features/right_view/73a84ac9-549c-4288-8614-88ae9a443603.npy, Shape: (142, 1, 512)

# %%
def custom_accuracy(predictions, targets):
    """
    Compute the accuracy based on the provided formula.
    Args:
        predictions (Tensor): The predicted labels.
        targets (Tensor): The ground truth labels.
    Returns:
        float: The accuracy.
    """
    correct_predictions = (predictions == targets).sum().item()
    accuracy = correct_predictions / targets.size(0)
    return accuracy

# %%
def custom_f1_score(predictions, labels):
    tp = 0  # (true positive) correct prediction of the maneuver in a video
    fp = 0  # (false predictions) prediction is different than the actual performed maneuver
    fpp = 0 # (false positive prediction) a maneuver-action predicted, but the driver is driving straight
    mp = 0  # (missed prediction) a driving-straight predicted, but a maneuver is performed

    for i in range(len(predictions)):
        if predictions[i] == labels[i]:
            tp += 1
        else:
            fp += 1

            # a maneuver-action predicted, but the driver is driving straight
            if predictions[i] == 1:
                mp += 1

            # a driving-straight predicted, but a maneuver is performed
            if labels[i] == 1:
                fpp += 1

    if tp + fp + fpp == 0:
        precision = 0
        return 0
    else:
        precision = tp / (tp + fp + fpp)

    if tp + fp + mp == 0:
        recall = 0
        return 0
    else:
        recall = tp / (tp + fp + mp)

    if precision + recall == 0:
        f1 = 0
    else:
        f1 = 2 * precision * recall / (precision + recall)

    return f1

# %%
import os
import glob
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class TestDataset(Dataset):
    def __init__(self, rootdir, seq_len=400, normalize_len=True, merge_views=False):
        self.rootdir = rootdir
        self.seq_len = seq_len
        self.normalize_len = normalize_len
        self.merge_views = merge_views
        self.views = ['frontal_view/VGG16_features', 'left_view', 'right_view']

        self.file_paths = {view: glob.glob(os.path.join(rootdir, view, '*.npy')) for view in self.views}

        if merge_views:
            num_files = len(self.file_paths['frontal_view/VGG16_features'])
            assert all(len(self.file_paths[view]) == num_files for view in self.views), "All views must have the same number of files."
            self.all_paths = list(zip(self.file_paths['frontal_view/VGG16_features'], self.file_paths['left_view'], self.file_paths['right_view']))
        else:
            self.all_paths = self.file_paths['frontal_view/VGG16_features']

    def __len__(self):
        return len(self.all_paths)

    def resize_sequence(self, features):
        if features.shape[0] < self.seq_len:
            diff = self.seq_len - features.shape[0]
            pad = np.zeros((diff, features.shape[1], features.shape[2]))  # Ensure pad has the same dimensions as features
            features = np.concatenate((features, pad), axis=0)
        else:
            mid_point = features.shape[0] // 2
            window_size = self.seq_len // 2
            features = features[int(mid_point - window_size): int(mid_point + window_size), :, :]
        return features

    def __getitem__(self, idx):
        if self.merge_views:
            paths = self.all_paths[idx]
            features_list = [np.load(path) for path in paths]
            filenames = [os.path.basename(path) for path in paths]
            if self.normalize_len:
                features_list = [self.resize_sequence(features) for features in features_list]
            features = np.stack(features_list, axis=2)  # shape: (seq_len, feature_dim, num_views)
            features = features.squeeze(1)  # Remove the singleton dimension
            features = torch.from_numpy(features).float()
            return {"features": features, "filenames": filenames}
        else:
            path = self.all_paths[idx]
            features = np.load(path)
            filename = os.path.basename(path)
            if self.normalize_len:
                features = self.resize_sequence(features)
            features = torch.from_numpy(features).float()
            return {"features": features, "filenames": [filename]}

def test_collate_fn(batch):
    features_list = [res["features"] for res in batch]
    filenames_list = [res["filenames"] for res in batch]

    features = torch.stack(features_list, dim=0)
    filenames = [filename for sublist in filenames_list for filename in sublist]
    return {
        "features": features,
        "filenames": filenames
    }

# %%
# Creating the Test DataLoaders
# rootdir = '/kaggle/input/riptide-test-new/VGG16_test_features'
rootdir = "/kaggle/working/VGG16_test_features"

# Test dataset and loader for multi-view (merged views)
test_dataset_multi = TestDataset(rootdir=rootdir, merge_views=True)
test_loader_multi = DataLoader(test_dataset_multi, batch_size=32, shuffle=False, collate_fn=test_collate_fn)

# Test dataset and loader for single-view (frontal view)
test_dataset_frontal = TestDataset(rootdir=rootdir, merge_views=False)
test_loader_frontal = DataLoader(test_dataset_frontal, batch_size=32, shuffle=False, collate_fn=test_collate_fn)

# Testing the DataLoaders
for i in test_loader_multi:
    print(i.keys())
    print(i['features'].shape)


for i in test_loader_frontal:
    print(i.keys())
    print(i['features'].shape)
# Out:
# dict_keys(['features', 'filenames'])
# torch.Size([32, 400, 3, 512])
# dict_keys(['features', 'filenames'])
# torch.Size([32, 400, 3, 512])
# dict_keys(['features', 'filenames'])
# torch.Size([32, 400, 3, 512])
# dict_keys(['features', 'filenames'])
# torch.Size([32, 400, 3, 512])
# dict_keys(['features', 'filenames'])
# torch.Size([32, 400, 3, 512])
# dict_keys(['features', 'filenames'])
# torch.Size([32, 400, 3, 512])
# dict_keys(['features', 'filenames'])
# torch.Size([32, 400, 3, 512])
# dict_keys(['features', 'filenames'])
# torch.Size([32, 400, 3, 512])
# dict_keys(['features', 'filenames'])
# torch.Size([32, 400, 3, 512])
# dict_keys(['features', 'filenames'])
# torch.Size([11, 400, 3, 512])
# dict_keys(['features', 'filenames'])
# torch.Size([32, 400, 1, 512])
# dict_keys(['features', 'filenames'])
# torch.Size([32, 400, 1, 512])
# dict_keys(['features', 'filenames'])
# torch.Size([32, 400, 1, 512])
# dict_keys(['features', 'filenames'])
# torch.Size([32, 400, 1, 512])
# dict_keys(['features', 'filenames'])
# torch.Size([32, 400, 1, 512])
# dict_keys(['features', 'filenames'])
# torch.Size([32, 400, 1, 512])
# dict_keys(['features', 'filenames'])
# torch.Size([32, 400, 1, 512])
# dict_keys(['features', 'filenames'])
# torch.Size([32, 400, 1, 512])
# dict_keys(['features', 'filenames'])
# torch.Size([32, 400, 1, 512])
# dict_keys(['features', 'filenames'])
# torch.Size([11, 400, 1, 512])

# %%
import torch.optim as optim
import wandb
import torch.nn as nn

class Model(nn.Module):
    def __init__(self, num_classes=6):
        super(Model, self).__init__()
        self.num_classes = num_classes

    def forward(self, x):
        return x

    def fit(self, train_loader, valid_loader, epochs, lr, weight_decay, early_stopping_patience, is_wandb=False, device='cuda', use_scheduler=False, save_name="model"):
        optimizer = optim.Adam(self.parameters(), lr=lr, weight_decay=weight_decay)
        criterion = nn.CrossEntropyLoss()
        scheduler = None

        if use_scheduler:
            scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.1)

        best_val_acc = 0
        patience_counter = 0

        for epoch in range(epochs):
            self.train()
            for batch_idx, data in enumerate(train_loader):
                features = data["features"]
                label = data["labels"]

                features = features.to(device)
                label = label.to(device)

                optimizer.zero_grad()
                output = self(features)
                loss = criterion(output, label)
                loss.backward()

                torch.nn.utils.clip_grad_norm_(self.parameters(), max_norm=1.0)

                optimizer.step()

                predictions = torch.argmax(output, dim=1)
                train_acc = custom_accuracy(predictions, label)
                train_f1 = custom_f1_score(predictions, label)

                if batch_idx % 100 == 0:
                    print(f"Epoch: {epoch+1} | Batch: {batch_idx} | CrossEntropyLoss: {loss.item():.3f} | Accuracy: {train_acc:.3f} | F1Score: {train_f1:.3f}")

            if scheduler:
                scheduler.step()

            self.eval()
            with torch.no_grad():
                val_f1_scores = []
                val_acc_scores = []
                for val_idx, val_data in enumerate(valid_loader):
                    val_features = val_data["features"]
                    val_label = val_data["labels"]

                    val_features = val_features.to(device)
                    val_label = val_label.to(device)

                    val_output = self(val_features)

                    val_predictions = torch.argmax(val_output, dim=1)
                    val_acc = custom_accuracy(val_predictions, val_label)
                    val_f1 = custom_f1_score(val_predictions, val_label)

                    val_f1_scores.append(val_f1)
                    val_acc_scores.append(val_acc)

                avg_val_f1_score = sum(val_f1_scores) / len(val_f1_scores)
                avg_val_acc_score = sum(val_acc_scores) / len(val_acc_scores)

                print(f"Validation -> Epoch: {epoch} | Accuracy: {avg_val_acc_score:.3f} | F1Score: {avg_val_f1_score:.3f}")

                # Early stopping check
                if avg_val_acc_score > best_val_acc:
                    best_val_acc = avg_val_acc_score
                    torch.save(self.state_dict(), f"{save_name}_best.pt")
                    print(f"Model saved with best validation accuracy: {best_val_acc:.3f} at epoch {epoch}")
                    patience_counter = 0  # Reset patience counter
                else:
                    patience_counter += 1

                if patience_counter >= early_stopping_patience:
                    print("Early stopping triggered")
                    break

            if epoch == epochs - 1:
                torch.save(self.state_dict(), f"{save_name}_last_epoch.pt")
                print(f"Model saved at the last epoch {epoch}")

# %%
class CNN_LSTM_MULTI(Model):
    def __init__(self, num_classes=6, lstm_layers=2, hidden_size=64, dropout_rate=0.25):
        super(CNN_LSTM_MULTI, self).__init__(num_classes)
        self.hidden_size = hidden_size
        self.lstm_layers = lstm_layers

        self.conv1 = nn.Conv1d(in_channels=512, out_channels=64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm1d(64)
        self.relu = nn.LeakyReLU()
        self.dropout = nn.Dropout(dropout_rate)

        self.lstm = nn.LSTM(64 * 3, hidden_size, batch_first=True, num_layers=lstm_layers, bidirectional=True, dropout=dropout_rate)
        self.fc = nn.Linear(hidden_size * 2, self.num_classes)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        batch_size, seq_len, num_views, feature_dim = x.size()
        # x: [32, 230, 3, 512]

        # Process each view separately
        features = []
        for view in range(num_views):
            view_x = x[:, :, view, :]
            view_x = view_x.transpose(1, 2)  # Transpose to [batch_size, feature_dim, seq_len]
            view_x = self.conv1(view_x)
            view_x = self.bn1(view_x)
            view_x = self.relu(view_x)
            view_x = self.dropout(view_x)
            view_x = view_x.transpose(1, 2)  # Transpose back to [batch_size, seq_len, feature_dim]
            features.append(view_x)

        # Concatenate features from all views
        x = torch.cat(features, dim=2)
        # x: [32, 230, 64 * 3]

        self.lstm.flatten_parameters()
        lstm_out, _ = self.lstm(x)
        # LSTM processing, output shape: [32, 230, hidden_size * 2]

        lstm_out = lstm_out[:, -1, :]
        # Get the output from the last time step, output shape: [32, hidden_size * 2]

        output = self.fc(lstm_out)
        # Fully connected layer, output shape: [32, num_classes]

        output = self.softmax(output)
        # Softmax, output shape: [32, num_classes]

        return output

# %%
class CNN_LSTM_FRONTAL(Model):
    def __init__(self, num_classes=6, lstm_layers=2, hidden_size=64, dropout_rate=0.25):
        super(CNN_LSTM_FRONTAL, self).__init__(num_classes)
        self.hidden_size = hidden_size
        self.lstm_layers = lstm_layers

        self.conv1 = nn.Conv1d(in_channels=512, out_channels=64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm1d(64)
        self.relu = nn.LeakyReLU()
        self.dropout = nn.Dropout(dropout_rate)

        self.lstm = nn.LSTM(64, hidden_size, batch_first=True, num_layers=lstm_layers, bidirectional=True, dropout=dropout_rate)
        self.fc = nn.Linear(hidden_size * 2, self.num_classes)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        batch_size, seq_len, num_views, feature_dim = x.size()
        # x: [32, 230, 1, 512]

        x = x.squeeze(2)  # Remove the dimension of size 1
        # x: [32, 230, 512]

        x = x.transpose(1, 2)  # Transpose to [batch_size, feature_dim, seq_len]
        # x: [32, 512, 230]

        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.dropout(x)
        # x: [32, 64, 230]

        x = x.transpose(1, 2)  # Transpose back to [batch_size, seq_len, feature_dim]
        # x: [32, 230, 64]

        self.lstm.flatten_parameters()
        lstm_out, _ = self.lstm(x)
        # LSTM processing, output shape: [32, 230, hidden_size * 2]

        lstm_out = lstm_out[:, -1, :]
        # Get the output from the last time step, output shape: [32, hidden_size * 2]

        output = self.fc(lstm_out)
        # Fully connected layer, output shape: [32, num_classes]

        output = self.softmax(output)
        # Softmax, output shape: [32, num_classes]

        return output

# %%
import pandas as pd
import torch

# %%
def run_inference_and_save_results(model, dataloader, output_csv_path):
    model.eval()
    results = []

    with torch.no_grad():
        for data in dataloader:
            features = data["features"]
            filenames = data["filenames"]

            features = features.to(device)
            outputs = model(features)

            predictions = torch.argmax(outputs, dim=1).cpu().numpy()

            for filename, prediction in zip(filenames, predictions):
                result = [filename] + [1 if i == prediction else 0 for i in range(6)]
                results.append(result)

    # Convert results to DataFrame
    columns = ['filename', 'Right Lane Change', 'Straight', 'Left Turn', 'Slow-Stop', 'Right Turn', 'Left Lane Change']
    results_df = pd.DataFrame(results, columns=columns)

    # Save to CSV
    results_df.to_csv(output_csv_path, index=False)

# %%
# Load the models
model_path_multi = '/kaggle/input/icpr-multi-25th-july/pytorch/default/1/cnn_lstm_multi_model_final_lr_0.001_dropout_0.25 (1) 64 66.pt'
model_path_frontal = '/kaggle/input/icpr-frontal-25th-july/pytorch/default/1/cnn_lstm_frontal_model_final_lr_0.001_dropout_0.25 68 71.pt'

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model_multi = CNN_LSTM_MULTI(num_classes=6, lstm_layers=2, hidden_size=128, dropout_rate=0.25)
model_multi.load_state_dict(torch.load(model_path_multi, map_location=device))
model_multi.to(device)
# Out:
# CNN_LSTM_MULTI(
#   (conv1): Conv1d(512, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (dropout): Dropout(p=0.25, inplace=False)
#   (lstm): LSTM(192, 128, num_layers=2, batch_first=True, dropout=0.25, bidirectional=True)
#   (fc): Linear(in_features=256, out_features=6, bias=True)
#   (softmax): Softmax(dim=1)
# )

# %%
model_frontal = CNN_LSTM_FRONTAL(num_classes=6, lstm_layers=2, hidden_size=128, dropout_rate=0.25)
model_frontal.load_state_dict(torch.load(model_path_frontal, map_location=device))
model_frontal.to(device)
# Out:
# CNN_LSTM_FRONTAL(
#   (conv1): Conv1d(512, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (dropout): Dropout(p=0.25, inplace=False)
#   (lstm): LSTM(64, 128, num_layers=2, batch_first=True, dropout=0.25, bidirectional=True)
#   (fc): Linear(in_features=256, out_features=6, bias=True)
#   (softmax): Softmax(dim=1)
# )

# %%
# Paths for saving results
output_csv_path_multi = '/kaggle/working/task2_test_result.csv'
output_csv_path_frontal = '/kaggle/working/task1_test_result.csv'

# %%
# Run inference and save results for multi-view
run_inference_and_save_results(model_multi, test_loader_multi, output_csv_path_multi)

# Run inference and save results for single-view (frontal)
run_inference_and_save_results(model_frontal, test_loader_frontal, output_csv_path_frontal)

print("Inference completed and results saved.")
# Out:
# Inference completed and results saved.
